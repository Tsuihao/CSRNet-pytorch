# %%
import h5py
import scipy.io as io
import PIL.Image as Image
import numpy as np
import os
import glob
from matplotlib import pyplot as plt
from scipy.ndimage.filters import gaussian_filter 
import scipy
import json
from matplotlib import cm as CM
from image import *
from model import CSRNet
import torch
# %matplotlib inline

# %%
#this is borrowed from https://github.com/davideverona/deep-crowd-counting_crowdnet
def gaussian_filter_density(gt):
    print gt.shape
    density = np.zeros(gt.shape, dtype=np.float32)
    gt_count = np.count_nonzero(gt)
    if gt_count == 0:
        return density

    pts = np.array(zip(np.nonzero(gt)[1], np.nonzero(gt)[0]))
    leafsize = 2048
    # build kdtree
    tree = scipy.spatial.KDTree(pts.copy(), leafsize=leafsize)
    # query kdtree
    distances, locations = tree.query(pts, k=4)

    print 'generate density...'
    for i, pt in enumerate(pts):
        pt2d = np.zeros(gt.shape, dtype=np.float32)
        pt2d[pt[1],pt[0]] = 1.
        if gt_count > 1:
            sigma = (distances[i][1]+distances[i][2]+distances[i][3])*0.1
        else:
            sigma = np.average(np.array(gt.shape))/2./2. #case: 1 point
        density += scipy.ndimage.filters.gaussian_filter(pt2d, sigma, mode='constant')
    print 'done.'
    return density

# %%
#set the root to the Shanghai dataset you download
root = '/media/htsui/4tb-transfer-192/dataset/Shanghai/'

# %%
#now generate the ShanghaiA's ground truth
part_A_train = os.path.join(root,'part_A_final/train_data','images')
part_A_test = os.path.join(root,'part_A_final/test_data','images')
part_B_train = os.path.join(root,'part_B_final/train_data','images')
part_B_test = os.path.join(root,'part_B_final/test_data','images')
path_sets = [part_A_train,part_A_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print img_path
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter_density(k)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
# Out:
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_39.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_293.jpg
# (686, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_191.jpg
# (682, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_141.jpg
# (427, 640)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_43.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_15.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_99.jpg
# (688, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_285.jpg
# (694, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_194.jpg
# (801, 688)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_66.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_29.jpg
# (450, 770)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_248.jpg
# (681, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_64.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_21.jpg
# (766, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_8.jpg
# (465, 700)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_89.jpg
# (410, 563)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_189.jpg
# (280, 692)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_41.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_185.jpg
# (800, 583)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_80.jpg
# (426, 634)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_97.jpg
# (366, 550)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_129.jpg
# (689, 998)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_213.jpg
# (749, 1000)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_38.jpg
# (566, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_195.jpg
# (665, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_177.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_297.jpg
# (685, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_254.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_154.jpg
# (416, 624)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_23.jpg
# (800, 600)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_175.jpg
# (360, 640)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_168.jpg
# (944, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_192.jpg
# (640, 480)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_91.jpg
# (387, 580)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_166.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_193.jpg
# (506, 487)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_245.jpg
# (825, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_165.jpg
# (274, 939)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_86.jpg
# (387, 580)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_287.jpg
# (716, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_170.jpg
# (480, 722)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_113.jpg
# (390, 600)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_57.jpg
# (1024, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_131.jpg
# (498, 390)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_36.jpg
# (388, 690)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_236.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_101.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_232.jpg
# (279, 400)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_273.jpg
# (598, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_2.jpg
# (713, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_73.jpg
# (544, 932)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_90.jpg
# (576, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_283.jpg
# (661, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_300.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_280.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_286.jpg
# (578, 779)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_156.jpg
# (625, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_221.jpg
# (679, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_281.jpg
# (680, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_229.jpg
# (430, 620)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_257.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_112.jpg
# (327, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_16.jpg
# (1024, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_140.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_186.jpg
# (653, 460)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_31.jpg
# (1024, 768)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_201.jpg
# (530, 800)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_267.jpg
# (521, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_202.jpg
# (530, 800)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_7.jpg
# (590, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_187.jpg
# (387, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_134.jpg
# (1024, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_207.jpg
# (442, 650)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_204.jpg
# (695, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_277.jpg
# (692, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_298.jpg
# (272, 511)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_3.jpg
# (664, 1000)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_216.jpg
# (293, 442)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_83.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_256.jpg
# (576, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_52.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_145.jpg
# (561, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_155.jpg
# (409, 620)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_119.jpg
# (594, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_35.jpg
# (653, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_222.jpg
# (522, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_239.jpg
# (328, 605)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_251.jpg
# (661, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_124.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_63.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_111.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_126.jpg
# (576, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_132.jpg
# (800, 600)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_180.jpg
# (386, 509)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_26.jpg
# (716, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_13.jpg
# (747, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_246.jpg
# (267, 400)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_243.jpg
# (681, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_81.jpg
# (282, 377)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_94.jpg
# (370, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_93.jpg
# (351, 620)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_37.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_12.jpg
# (680, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_87.jpg
# (416, 620)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_17.jpg
# (478, 600)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_291.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_123.jpg
# (774, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_51.jpg
# (656, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_159.jpg
# (267, 400)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_255.jpg
# (701, 749)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_212.jpg
# (688, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_242.jpg
# (667, 1000)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_118.jpg
# (651, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_76.jpg
# (563, 832)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_148.jpg
# (680, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_161.jpg
# (480, 640)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_106.jpg
# (675, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_188.jpg
# (649, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_61.jpg
# (683, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_75.jpg
# (681, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_184.jpg
# (617, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_54.jpg
# (564, 832)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_233.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_234.jpg
# (768, 1024)
# generate density...
# done.
# /media/htsui/4tb-transfer-192/dataset/Shanghai/part_A_final/train_data/images/IMG_122.jpg
# (787, 1024)
# generate density...

# %%
#now see a sample from ShanghaiA
plt.imshow(Image.open(img_paths[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-828cd2603834> in <module>()
#       1 #now see a sample from ShanghaiA
# ----> 2 plt.imshow(Image.open(img_paths[0]))
#
# IndexError: list index out of range

# %%
gt_file = h5py.File(img_paths[0].replace('.jpg','.h5').replace('images','ground_truth'),'r')
groundtruth = np.asarray(gt_file['density'])
plt.imshow(groundtruth,cmap=CM.jet)

# %%
np.sum(groundtruth)# don't mind this slight variation

# %%
#now generate the ShanghaiB's ground truth
path_sets = [part_B_train,part_B_test]

# %%
img_paths = []
for path in path_sets:
    for img_path in glob.glob(os.path.join(path, '*.jpg')):
        img_paths.append(img_path)

# %%
for img_path in img_paths:
    print img_path
    mat = io.loadmat(img_path.replace('.jpg','.mat').replace('images','ground_truth').replace('IMG_','GT_IMG_'))
    img= plt.imread(img_path)
    k = np.zeros((img.shape[0],img.shape[1]))
    gt = mat["image_info"][0,0][0,0][0]
    for i in range(0,len(gt)):
        if int(gt[i][1])<img.shape[0] and int(gt[i][0])<img.shape[1]:
            k[int(gt[i][1]),int(gt[i][0])]=1
    k = gaussian_filter(k,15)
    with h5py.File(img_path.replace('.jpg','.h5').replace('images','ground_truth'), 'w') as hf:
            hf['density'] = k
